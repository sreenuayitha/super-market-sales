# %%
#importing the modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_rows', 1100)
pd.set_option('display.max_columns', 100)

# %%
# importing the dataset super market sales data

df=pd.read_csv( '/Users/sreenu/Downloads/supermarket_sales - Sheet1.csv')
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# 5    699-14-3026      C  Naypyitaw        Normal    Male
# 6    355-53-5943      A     Yangon        Member  Female
# 7    315-22-5665      C  Naypyitaw        Normal  Female
# 8    665-32-9167      A     Yangon        Member  Female
# 9    692-92-5582      B   Mandalay        Member  Female
# 10   351-62-0822      B   Mandalay        Member  Female
# 11   529-56-3974      B   Mandalay        Member    Male
# 12   365-64-0515      A     Yangon        Normal  Female
# 13   252-56-2699      A     Yangon        Normal    Male
# 14   829-34-3910      A     Yangon        Normal  Female
# ...

# %%
# retreving the data top 5 rows

df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
# reading the columns names present in the dataset
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
#checking the information of the dataset or finding the null values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
# checking the unqiue values
df.nunique()
# Out:
# Invoice ID                 1000
# Branch                        3
# City                          3
# Customer type                 2
# Gender                        2
# Product line                  6
# Unit price                  943
# Quantity                     10
# Tax 5%                      990
# Total                       990
# Date                         89
# Time                        506
# Payment                       3
# cogs                        990
# gross margin percentage       1
# gross income                990
# Rating                       61
# dtype: int64

# %% [raw]
# so the unique values is there in the data set so first we the drop the coloumn invoice id

# %%
# first check the shape of the dataset and drop the the column and after print shape of dataset

print(df.shape)
df.drop('Invoice ID',axis=1,inplace=True)
print(df.shape)
# Out:
# (1000, 17)
# (1000, 16)

# %%
df.head()
# Out:
#   Branch       City Customer type  Gender            Product line  Unit price  \
# 0      A     Yangon        Member  Female       Health and beauty       74.69
# 1      C  Naypyitaw        Normal  Female  Electronic accessories       15.28
# 2      A     Yangon        Normal    Male      Home and lifestyle       46.33
# 3      A     Yangon        Member    Male       Health and beauty       58.22
# 4      A     Yangon        Normal    Male       Sports and travel       86.31
#
#    Quantity   Tax 5%     Total       Date   Time      Payment    cogs  \
# 0         7  26.1415  548.9715   1/5/2019  13:08      Ewallet  522.83
# 1         5   3.8200   80.2200   3/8/2019  10:29         Cash   76.40
# 2         7  16.2155  340.5255   3/3/2019  13:23  Credit card  324.31
# 3         8  23.2880  489.0480  1/27/2019  20:33      Ewallet  465.76
# 4         7  30.2085  634.3785   2/8/2019  10:37      Ewallet  604.17
#
#    gross margin percentage  gross income  Rating
# ...

# %% [markdown]
# ## uni-varients

# %%
# check the cardnality function
y=df['Branch'].value_counts()
y
# Out:
# A    340
# B    332
# C    328
# Name: Branch, dtype: int64

# %%
# ploting the graph cardnality of the brach it is categerical column

plt.figure(figsize=(4,4))
df['Branch'].value_counts().plot.bar()
plt.xticks(rotation=0)
plt.title('cardnality of branch')


plt.show()

# %%
# sencod checking the cardnality of city

df['City'].value_counts()
# Out:
# Yangon       340
# Mandalay     332
# Naypyitaw    328
# Name: City, dtype: int64

# %% [raw]
# only three city sales are there  in this dataset

# %%
# uni varient of city plot
plt.figure(figsize=(5,5))
df['City'].value_counts().plot.bar()
plt.title("City names")
plt.xticks(rotation=0)
plt.show()

# %%
# checking the crosstab of branch and city
z=pd.crosstab(df['Branch'],df['City'])
z
# Out:
# City    Mandalay  Naypyitaw  Yangon
# Branch
# A              0          0     340
# B            332          0       0
# C              0        328       0

# %% [raw]
# ho its good only one branch deals with one city only as shown in above

# %%
# checking the cardnality of customer type
df['Customer type'].value_counts()    # only two types of customers
# Out:
# Member    501
# Normal    499
# Name: Customer type, dtype: int64

# %%
# ploting  the graph checking the customer type
plt.figure(figsize=(5,5))
df["Customer type"].value_counts().plot.barh()
plt.title('customer type')
plt.xticks(rotation=0)
plt.show()

# %%
# checking the value_counts of product line and finding no. of items is there in this data 
df['Product line'].value_counts()
# Out:
# Fashion accessories       178
# Food and beverages        174
# Electronic accessories    170
# Sports and travel         166
# Home and lifestyle        160
# Health and beauty         152
# Name: Product line, dtype: int64

# %%
df['Product line'].value_counts().plot.bar()
plt.xticks(rotation=45)
plt.title('items of sales')
plt.show()

# %%
df['Quantity'].value_counts()
# Out:
# 10    119
# 1     112
# 4     109
# 7     102
# 5     102
# 6      98
# 9      92
# 2      91
# 3      90
# 8      85
# Name: Quantity, dtype: int64

# %%
# sales of product no.of quantity and values
df['Quantity'].value_counts().plot.bar()
plt.xticks(rotation=0)
plt.title('no. of quantity sales')
plt.show()

# %%
import warnings
warnings.filterwarnings('ignore')
  #  checking outlier of the unite prize
sns.boxplot(df['Unit price'])
plt.title('unit price')
plt.show()

# %%
df['Payment'].value_counts()
# Out:
# Ewallet        345
# Cash           344
# Credit card    311
# Name: Payment, dtype: int64

# %%
plt.pie(df['Payment'].value_counts(),autopct='%.1f%%',labels=['Ewallet','cash','credit card'])
plt.title('types of payments')
plt.show()

# %%
# outliers of cogs
sns.boxplot(df['cogs'])
plt.title('cogs')
plt.show()

# %%
# i saw the total counts of recoreds
df['Rating'].count()
# Out:
# 1000

# %% [markdown]
# ## bi-varients

# %%
# seeing the product wise rating
pd.crosstab(df['Product line'],df['Rating'])
# Out:
# Rating                  4.0   4.1   4.2   4.3   4.4   4.5   4.6   4.7   4.8   \
# Product line
# Electronic accessories     1     3     2     4     3     1     0     6     3
# Fashion accessories        2     4     2     1     3     4     2     1     3
# Food and beverages         4     1     4     2     4     4     2     0     2
# Health and beauty          3     1     5     4     2     0     2     1     2
# Home and lifestyle         0     4     4     5     4     3     1     4     2
# Sports and travel          1     4     5     2     1     5     1     0     1
#
# Rating                  4.9   5.0   5.1   5.2   5.3   5.4   5.5   5.6   5.7   \
# Product line
# Electronic accessories     3     3     3     2     2     2     6     2     1
# Fashion accessories        5     5     1     4     2     1     3     3     4
# Food and beverages         1     3     2     3     0     3     3     4     1
# Health and beauty          4     5     5     0     4     0     3     3     2
# ...

# %%
# grouping the values product wise rating

df.groupby('Product line')[['Rating']].count()
# Out:
#                         Rating
# Product line
# Electronic accessories     170
# Fashion accessories        178
# Food and beverages         174
# Health and beauty          152
# Home and lifestyle         160
# Sports and travel          166

# %%
# ploting the graph product line vs rating of products

df.groupby('Product line')[['Rating']].count().plot.barh()
plt.title('product line vs rating')
plt.show()

# %%
# checking the customer type according to the branch useing the crosstab
pd.crosstab(df['Branch'],df['Customer type'])
# Out:
# Customer type  Member  Normal
# Branch
# A                 167     173
# B                 165     167
# C                 169     159

# %%
# ploting the graph branch vs customer type
plt.figure(figsize=(10,5))

pd.crosstab(df['Branch'],df['Customer type']).plot.bar()
plt.xticks(rotation=0)
plt.title('branch vs customer type')
plt.show()

# %%
# checking the cardnality of gender

df['Gender'].value_counts()
# Out:
# Female    501
# Male      499
# Name: Gender, dtype: int64

# %%
# checking the gender vs customer type

pd.crosstab(df['Gender'],df['Customer type'])
# Out:
# Customer type  Member  Normal
# Gender
# Female            261     240
# Male              240     259

# %%
# checking the gender vs customer type

pd.crosstab(df['Gender'],df['Customer type']).plot.barh()
plt.show()

# %%
# compareing branch and gross income
z=df.groupby('Branch')[['gross income']].sum()
z
# Out:
#         gross income
# Branch
# A          5057.1605
# B          5057.0320
# C          5265.1765

# %%
z.plot.barh()
plt.xticks(rotation=0)
plt.title("branch wise gross income")

plt.show()

# %%
df.columns
# Out:
# Index(['Branch', 'City', 'Customer type', 'Gender', 'Product line',
#        'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date', 'Time', 'Payment',
#        'cogs', 'gross margin percentage', 'gross income', 'Rating'],
#       dtype='object')

# %%
# checking the product line with uints price
q=pd.crosstab(df['Unit price'],df['Product line']).sum()
q
# Out:
# Product line
# Electronic accessories    170
# Fashion accessories       178
# Food and beverages        174
# Health and beauty         152
# Home and lifestyle        160
# Sports and travel         166
# dtype: int64

# %%
# showing the graph of the above cell
q.plot.barh()
plt.show()

# %%
# checking the product sales with the income wise
df.groupby('Product line')[['gross income']].sum()
# Out:
#                         gross income
# Product line
# Electronic accessories     2587.5015
# Fashion accessories        2585.9950
# Food and beverages         2673.5640
# Health and beauty          2342.5590
# Home and lifestyle         2564.8530
# Sports and travel          2624.8965

# %%
# ploting the graph of the income
df.groupby('Product line')[['gross income']].sum().plot.bar()
plt.title('product line vs gross income')
plt.xticks(rotation=45)
plt.show()

# %%
# unti price and sales of product
df.groupby('Product line')[['Unit price']].sum()
# Out:
#                         Unit price
# Product line
# Electronic accessories     9103.77
# Fashion accessories       10173.35
# Food and beverages         9745.54
# Health and beauty          8337.88
# Home and lifestyle         8850.71
# Sports and travel          9460.88

# %%
# One categorical & One numberical
plt.figure(figsize=(15,7))
sns.boxplot(x=df['Product line'],y=df['Unit price']);
plt.title('product item vs unit price')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# in sligh they are no outliers

# %%
# One categorical & One numberical
plt.figure(figsize=(15,7))
sns.boxplot(x=df['Product line'],y=df['gross income']);
plt.title('product items vs gross income')
plt.xticks(rotation=45)
plt.show()

# %%
df.columns
# Out:
# Index(['Branch', 'City', 'Customer type', 'Gender', 'Product line',
#        'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date', 'Time', 'Payment',
#        'cogs', 'gross margin percentage', 'gross income', 'Rating'],
#       dtype='object')

# %%
df.groupby('Product line')[['Total']].sum()
# Out:
#                              Total
# Product line
# Electronic accessories  54337.5315
# Fashion accessories     54305.8950
# Food and beverages      56144.8440
# Health and beauty       49193.7390
# Home and lifestyle      53861.9130
# Sports and travel       55122.8265

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(df['Product line'], df['gross income'], hue=df['Gender']);
plt.xticks(rotation=15)
plt.show()

# %%
df.groupby('Product line')[['gross income']].sum()
# Out:
#                         gross income
# Product line
# Electronic accessories     2587.5015
# Fashion accessories        2585.9950
# Food and beverages         2673.5640
# Health and beauty          2342.5590
# Home and lifestyle         2564.8530
# Sports and travel          2624.8965

# %%
import warnings
warnings.filterwarnings("ignore")
plt.figure(figsize=(10,8))
df.groupby('Product line')[['gross income']].sum().plot.pie(subplots=True,autopct='%1.1f%%');
plt.xticks(rotation=15)
plt.legend(title='products',loc=4,ncol=(3))
plt.show()

# %% [markdown]
# ## multi-vareinace

# %%
df.columns
# Out:
# Index(['Branch', 'City', 'Customer type', 'Gender', 'Product line',
#        'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date', 'Time', 'Payment',
#        'cogs', 'gross margin percentage', 'gross income', 'Rating'],
#       dtype='object')

# %%
fig, ax = plt.subplots()

plt.figure(figsize=((10,8)))
scat = ax.scatter(x=df['Product line'], y=df['gross income'],s=200, marker='o')
fig.colorbar(scat)

# %%
# multi varintes used in the slight

#plt.figure(figsize=(10,8))
g = sns.relplot(x=df['Product line'], y=df['gross income'], hue=df['Gender'],
                col=df['City'], row=df['Branch'], data=df)

# %%
#this is update graph of the above cell
g = sns.relplot(x=df['Product line'], y=df["gross income"], hue=df['Gender'], size=df['City'],
                 sizes=(10, 100),
                col=df["Branch"], data=df)
